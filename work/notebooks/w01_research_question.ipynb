# %% [markdown]
# # ML-02 — Research Question and Provisional Lane
#
# [![Open In Colab](https://colab.research.google.com/assets/colab-badge.svg)](https://colab.research.google.com/github/Urmila1945/flyrank-ml/blob/main/work/notebooks/w01_research_question.ipynb?flush_cache=true)
#
# This skeleton is yours to fill. Work the sections **in order** — each one has a one-line hint. Simple words, honest numbers.
#
# > Working with an AI assistant? Tell it to read `skills/README.md` first and load the one skill this assignment names on its card.

# %% [markdown]
# ## 1. My lane (or freestyle) and why
#
# *Name your lane — or say 'freestyle' and describe your own question. One short paragraph: why this one?*

# %%
"""
I selected the SEO Content Performance Prediction lane.

This project aims to understand which webpage features contribute to better search performance.
"""
# Out:
# '\nI selected the SEO Content Performance Prediction lane.\n\nThis project aims to understand which webpage features contribute to better search performance.\n'

# %% [markdown]
# ## 2. The question: decision, action, cost of a wrong call
#
# *What decision does your work improve? Who acts on it? What does a wrong recommendation cost?*

# %%
# Research Question

""" Decision:
Should a webpage be published as it is or improved before publication?

Action:
If the model predicts poor performance, improve the content by updating titles, headings, keywords, or structure before publishing.

Cost of a Wrong Prediction:
If a poor page is predicted as good, it may receive low traffic and reduce business opportunities.
If a good page is predicted as poor, unnecessary editing may waste time and resources.

Why ML?
Many webpage characteristics interact together. Machine learning can learn complex patterns that are difficult to identify using simple rules."""
# Out:
# ' Decision:\nShould a webpage be published as it is or improved before publication?\n\nAction:\nIf the model predicts poor performance, improve the content by updating titles, headings, keywords, or structure before publishing.\n\nCost of a Wrong Prediction:\nIf a poor page is predicted as good, it may receive low traffic and reduce business opportunities.\nIf a good page is predicted as poor, unnecessary editing may waste time and resources.\n\nWhy ML?\nMany webpage characteristics interact together. Machine learning can learn complex patterns that are difficult to identify using simple rules.'

# %% [markdown]
# ## 3. Quick look at the data (2-3 real numbers)
#
# *Load the starter CSV below and show 2-3 real numbers that make your lane look worth the next 7 weeks.*

# %%
# This cell is for CODE (numbers, a query, a check).
# Write your text answer in the cell ABOVE this one — typing sentences here breaks Run All.
import pandas as pd

df = pd.read_csv("../../data/content_refresh_anonymized.csv")   # use the actual dataset name in your repo

print("Rows:", len(df))
print("Columns:", len(df.columns))

print(df.describe())

# %% [markdown]
# ## 4. Careful words: what I can and can't claim
#
# *Write what your work will be able to say (observed, directional, decision-support) — and what it never will (causal proof, 'predicting Google').*

# %% [markdown]
# """Machine learning identifies statistical relationships rather than proving cause and effect.
#
# The model may not generalize to all websites because the dataset represents a specific collection of search data.
#
# The predictions should support human decisions rather than replace them."""

# %% [markdown]
# ## Self-check
#
# Before you submit, confirm each line honestly:
#
# - [ ] Every section above is filled — markdown thinking AND the code that backs it
# - [ ] The notebook runs top to bottom with no errors (Runtime → Run all)
# - [ ] No client names, URLs, or private queries anywhere
# - [ ] My claims use careful words: observed, measured, directional, decision-support
# - [ ] Committed to my repo under `work/notebooks/` — then submit your repo URL on the card. Done.
